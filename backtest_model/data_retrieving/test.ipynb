# %%
import json
with open("sample.json") as file:
    data=json.load(file)

# %%
lists=[]
for i in range(len(data)):
    lists.append((data[i]['symbol']).lower()+"@trade")

# %%
lists
# Out:
# ['ethbtc@trade',
#  'ltcbtc@trade',
#  'bnbbtc@trade',
#  'neobtc@trade',
#  'qtumeth@trade',
#  'eoseth@trade',
#  'snteth@trade',
#  'bnteth@trade',
#  'bccbtc@trade',
#  'gasbtc@trade',
#  'bnbeth@trade',
#  'btcusdt@trade',
#  'ethusdt@trade',
#  'hsrbtc@trade',
#  'oaxeth@trade',
#  'dnteth@trade',
#  'mcoeth@trade',
#  'icneth@trade',
#  'mcobtc@trade',
#  'wtcbtc@trade',
#  'wtceth@trade',
#  'lrcbtc@trade',
#  'lrceth@trade',
#  'qtumbtc@trade',
#  'yoyobtc@trade',
#  'omgbtc@trade',
#  'omgeth@trade',
#  'zrxbtc@trade',
#  'zrxeth@trade',
#  'stratbtc@trade',
#  'strateth@trade',
#  'snglsbtc@trade',
#  'snglseth@trade',
#  'bqxbtc@trade',
#  'bqxeth@trade',
#  'kncbtc@trade',
#  'knceth@trade',
#  'funbtc@trade',
#  'funeth@trade',
#  'snmbtc@trade',
#  'snmeth@trade',
#  'neoeth@trade',
#  'iotabtc@trade',
#  'iotaeth@trade',
#  'linkbtc@trade',
#  'linketh@trade',
#  'xvgbtc@trade',
#  'xvgeth@trade',
#  'saltbtc@trade',
#  'salteth@trade',
#  'mdabtc@trade',
# ...
